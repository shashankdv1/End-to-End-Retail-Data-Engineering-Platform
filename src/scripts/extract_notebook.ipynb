# %%
from extract import extract_data

df_products, df_clicks, df_sales = extract_data()
# Out:
# Extracting data from REST API...
# Generating User Click logs via Faker...
# Extracting historical transactions from SQLite3 Database
